# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("C://Users//ronak//Downloads//car data.csv")

# %%
df
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Selling_type Transmission  Owner
# 0         Dealer       Manual      0
# 1         Dealer       Manual      0
# 2         Dealer       Manual      0
# 3         Dealer       Manual      0
# 4         Dealer       Manual      0
# ..           ...          ...    ...
# 296       Dealer       Manual      0
# 297       Dealer       Manual      0
# 298       Dealer       Manual      0
# 299       Dealer       Manual      0
# 300       Dealer       Manual      0
#
# [301 rows x 9 columns]

# %%
#Exploratory Data Analysis

# %%
print(" First few rows of the dataset:")
df.head()
# Out:
#  First few rows of the dataset:
#   Car_Name  Year  Selling_Price  Present_Price  Driven_kms Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Selling_type Transmission  Owner
# 0       Dealer       Manual      0
# 1       Dealer       Manual      0
# 2       Dealer       Manual      0
# 3       Dealer       Manual      0
# 4       Dealer       Manual      0

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
df.shape
# Out:
# (301, 9)

# %%
df.describe().style.format(precision=2).background_gradient(cmap='RdBu')
# Out:
# <style type="text/css">
# #T_435fb_row0_col0 {
#   background-color: #c2383a;
#   color: #f1f1f1;
# }
# #T_435fb_row0_col1, #T_435fb_row0_col2, #T_435fb_row0_col4, #T_435fb_row1_col0, #T_435fb_row4_col0, #T_435fb_row5_col0, #T_435fb_row6_col0, #T_435fb_row7_col0, #T_435fb_row7_col3 {
#   background-color: #053061;
#   color: #f1f1f1;
# }
# #T_435fb_row0_col3, #T_435fb_row1_col4, #T_435fb_row2_col0, #T_435fb_row2_col4, #T_435fb_row3_col1, #T_435fb_row3_col2, #T_435fb_row3_col3, #T_435fb_row3_col4, #T_435fb_row4_col1, #T_435fb_row4_col2, #T_435fb_row4_col4, #T_435fb_row5_col4, #T_435fb_row6_col4 {
#   background-color: #67001f;
#   color: #f1f1f1;
# }
# #T_435fb_row1_col1 {
#   background-color: #700320;
#   color: #f1f1f1;
# }
# #T_435fb_row1_col2 {
#   background-color: #790622;
#   color: #f1f1f1;
# }
# #T_435fb_row1_col3 {
#   background-color: #9c1127;
#   color: #f1f1f1;
# }
# #T_435fb_row2_col1 {
#   background-color: #730421;
#   color: #f1f1f1;
# }
# #T_435fb_row2_col2, #T_435fb_row4_col3 {
#   background-color: #7c0722;
#   color: #f1f1f1;
# }
# #T_435fb_row2_col3 {
#   background-color: #9f1228;
#   color: #f1f1f1;
# }
# #T_435fb_row3_col0 {
#   background-color: #063264;
#   color: #f1f1f1;
# }
# #T_435fb_row5_col1, #T_435fb_row7_col4 {
#   background-color: #6d0220;
#   color: #f1f1f1;
# }
# #T_435fb_row5_col2, #T_435fb_row6_col1 {
#   background-color: #760521;
#   color: #f1f1f1;
# }
# #T_435fb_row5_col3 {
#   background-color: #960f27;
#   color: #f1f1f1;
# }
# #T_435fb_row6_col2 {
#   background-color: #7f0823;
#   color: #f1f1f1;
# }
# #T_435fb_row6_col3 {
#   background-color: #ae172a;
#   color: #f1f1f1;
# }
# #T_435fb_row7_col1 {
#   background-color: #b72230;
#   color: #f1f1f1;
# }
# #T_435fb_row7_col2 {
#   background-color: #f5a886;
#   color: #000000;
# }
# </style>
# <table id="T_435fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_435fb_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_435fb_level0_col1" class="col_heading level0 col1" >Selling_Price</th>
#       <th id="T_435fb_level0_col2" class="col_heading level0 col2" >Present_Price</th>
#       <th id="T_435fb_level0_col3" class="col_heading level0 col3" >Driven_kms</th>
#       <th id="T_435fb_level0_col4" class="col_heading level0 col4" >Owner</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_435fb_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_435fb_row0_col0" class="data row0 col0" >301.00</td>
#       <td id="T_435fb_row0_col1" class="data row0 col1" >301.00</td>
#       <td id="T_435fb_row0_col2" class="data row0 col2" >301.00</td>
#       <td id="T_435fb_row0_col3" class="data row0 col3" >301.00</td>
#       <td id="T_435fb_row0_col4" class="data row0 col4" >301.00</td>
#     </tr>
#     <tr>
#       <th id="T_435fb_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_435fb_row1_col0" class="data row1 col0" >2013.63</td>
#       <td id="T_435fb_row1_col1" class="data row1 col1" >4.66</td>
#       <td id="T_435fb_row1_col2" class="data row1 col2" >7.63</td>
#       <td id="T_435fb_row1_col3" class="data row1 col3" >36947.21</td>
#       <td id="T_435fb_row1_col4" class="data row1 col4" >0.04</td>
#     </tr>
#     <tr>
#       <th id="T_435fb_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_435fb_row2_col0" class="data row2 col0" >2.89</td>
#       <td id="T_435fb_row2_col1" class="data row2 col1" >5.08</td>
#       <td id="T_435fb_row2_col2" class="data row2 col2" >8.64</td>
#       <td id="T_435fb_row2_col3" class="data row2 col3" >38886.88</td>
#       <td id="T_435fb_row2_col4" class="data row2 col4" >0.25</td>
#     </tr>
#     <tr>
#       <th id="T_435fb_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_435fb_row3_col0" class="data row3 col0" >2003.00</td>
#       <td id="T_435fb_row3_col1" class="data row3 col1" >0.10</td>
#       <td id="T_435fb_row3_col2" class="data row3 col2" >0.32</td>
#       <td id="T_435fb_row3_col3" class="data row3 col3" >500.00</td>
#       <td id="T_435fb_row3_col4" class="data row3 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_435fb_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_435fb_row4_col0" class="data row4 col0" >2012.00</td>
#       <td id="T_435fb_row4_col1" class="data row4 col1" >0.90</td>
#       <td id="T_435fb_row4_col2" class="data row4 col2" >1.20</td>
#       <td id="T_435fb_row4_col3" class="data row4 col3" >15000.00</td>
#       <td id="T_435fb_row4_col4" class="data row4 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_435fb_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_435fb_row5_col0" class="data row5 col0" >2014.00</td>
#       <td id="T_435fb_row5_col1" class="data row5 col1" >3.60</td>
#       <td id="T_435fb_row5_col2" class="data row5 col2" >6.40</td>
#       <td id="T_435fb_row5_col3" class="data row5 col3" >32000.00</td>
#       <td id="T_435fb_row5_col4" class="data row5 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_435fb_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_435fb_row6_col0" class="data row6 col0" >2016.00</td>
#       <td id="T_435fb_row6_col1" class="data row6 col1" >6.00</td>
#       <td id="T_435fb_row6_col2" class="data row6 col2" >9.90</td>
#       <td id="T_435fb_row6_col3" class="data row6 col3" >48767.00</td>
#       <td id="T_435fb_row6_col4" class="data row6 col4" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_435fb_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_435fb_row7_col0" class="data row7 col0" >2018.00</td>
#       <td id="T_435fb_row7_col1" class="data row7 col1" >35.00</td>
#       <td id="T_435fb_row7_col2" class="data row7 col2" >92.60</td>
#       <td id="T_435fb_row7_col3" class="data row7 col3" >500000.00</td>
#       <td id="T_435fb_row7_col4" class="data row7 col4" >3.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Driven_kms     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Selling_type   301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
print('Missing Values')
df.isnull().sum()
# Out:
# Missing Values
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Driven_kms       0
# Fuel_Type        0
# Selling_type     0
# Transmission     0
# Owner            0
# dtype: int64

# %%
print("Data types of columns:")
print(df.dtypes)
# Out:
# Data types of columns:
# Car_Name          object
# Year               int64
# Selling_Price    float64
# Present_Price    float64
# Driven_kms         int64
# Fuel_Type         object
# Selling_type      object
# Transmission      object
# Owner              int64
# dtype: object

# %%
print('Duplicate Values:')
df.duplicated().sum()
# Out:
# Duplicate Values:
# 2

# %%
df=df.drop_duplicates()
df.duplicated().sum()
# Out:
# 0

# %%
#Data visualization and EDA

# %%
plt.figure(figsize=(10,6))
sns.boxplot(df['Selling_Price'],palette='pastel')
plt.title('Boxplot of Selling Price')
plt.show()

# %%
numerical_columns = ['Year', 'Selling_Price', 'Present_Price', 'Driven_kms', 'Owner']

numerical_df = df[numerical_columns]

correlation_matrix = numerical_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap (Numerical Columns)')
plt.show()

# %%
numerical_features=['Year','Driven_kms','Selling_Price','Present_Price']
for feature in numerical_features:
    plt.figure(figsize=(10,6))
    sns.displot(data=df,x=feature,kde=True)
    plt.title(f'Distribution of {feature}')
    plt.show()

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='Driven_kms',y='Selling_Price',data=df)
plt.title('Relationship between Driven_kms and Selling_Price')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='Present_Price', y='Selling_Price', data=df)
plt.title('Relationship between Present_Price and Selling_Price')
plt.xlabel('Present Price')
plt.ylabel('Selling Price')

plt.show()

# %%
colors=sns.color_palette("Set2")
categorical_features=['Fuel_Type', 'Selling_type', 'Transmission','Owner']


for feature in categorical_features:
    plt.figure(figsize=(10,6))
    sns.countplot(x=feature,data=df,palette=colors)
    plt.title(f'Frequency of {feature}',fontsize=16,color='darkblue',fontweight='bold')
    plt.xlabel(f'{feature}',fontsize=14,color='navy')
    plt.ylabel('Frequency',fontsize=14,color='navy')
    plt.yticks(fontsize=12)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %%
df.columns
# Out:
# Index(['Car_Name', 'Year', 'Selling_Price', 'Present_Price', 'Driven_kms',
#        'Fuel_Type', 'Selling_type', 'Transmission', 'Owner'],
#       dtype='object')

# %%
n = 20  
top_car_models = df['Car_Name'].value_counts().head(n)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_car_models.values, y=top_car_models.index)
plt.title(f'Top {n} Car Models by Frequency')
plt.xlabel('Frequency')
plt.ylabel('Car Model')
plt.tight_layout()
plt.show()
